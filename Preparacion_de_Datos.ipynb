# %%
#Importando librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  # Libreria para los graficos
import seaborn as sb #Sobrecapa de matplotlib graficos estadisticos 
import os

# %%
#Esta linea nos permite que los graficos sean renderizados directamente en nuestro notebook
#Cargamos un pandas dataframe , nuestra bd
#Nos permite al momento de graficar que aparezcan en el mismo notebook
# %matplotlib inline

# %%
#Nos permite importar los datos desde un csv y descargarlo en un dataframe, que es la estructura de pandas
#print(os.getcwd()) Nos permite ver el directorio actual
movies=pd.read_csv('DATOS\peliculas.csv',encoding='utf-8') #Nos dijimos al directorio donde tenemos el .csv

# %%
type(movies) # Es objeto Dataframe , con columnas y indices
# Out:
# pandas.core.frame.DataFrame

# %%
movies.head() # 5 primeros elementos de un DataFrame
# Out:
#                                          movie_title  title_year  color  \
# 0                                            Avatar       2009.0  Color
# 1          Pirates of the Caribbean: At World's End       2007.0  Color
# 2                                           Spectre       2015.0  Color
# 3                             The Dark Knight Rises       2012.0  Color
# 4  Star Wars: Episode VII - The Force Awakens    ...         NaN    NaN
#
#    aspect_ratio  duration language country  duration.1  \
# 0          1.78     178.0  English     USA       178.0
# 1          2.35     169.0  English     USA       169.0
# 2          2.35     148.0  English      UK       148.0
# 3          2.35     164.0  English     USA       164.0
# 4           NaN       NaN      NaN     NaN         NaN
#
#                             genres content_rating  \
# 0  Action|Adventure|Fantasy|Sci-Fi          PG-13
# 1         Action|Adventure|Fantasy          PG-13
# ...

# %%
movies.shape
# Out:
# (5043, 19)

# %%
movies.columns #Columnas del dataframe
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
#Indices del datarfame
movies.index
# Out:
# RangeIndex(start=0, stop=5043, step=1)

# %%
columna1 = movies['movie_title']

# %%
columna1.head() #Nos trae todo lo de esa columna es como el select movie_title from movies;
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
movies.loc[:,'movie_title'] #Todos los registros de la columa movie_tittle
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                             Signed Sealed Delivered
# 5039                           The Following
# 5040                                A Plague So Pleasant
# 5041                                    Shanghai Calling
# 5042                                   My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %%
movies.loc[:,'movie_title'].head()
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
movies.loc[:5,'movie_title']
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# 5                                         John Carter
# Name: movie_title, dtype: object

# %%
movies.info() #Arroja el tipo de la columna y cuantos campos no nulos tiene, se hace para entender los datos mejor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                5043 non-null   object
#  1   title_year                 4935 non-null   float64
#  2   color                      5024 non-null   object
#  3   aspect_ratio               4714 non-null   float64
#  4   duration                   5028 non-null   float64
#  5   language                   5031 non-null   object
#  6   country                    5038 non-null   object
#  7   duration.1                 5028 non-null   float64
#  8   genres                     5043 non-null   object
#  9   content_rating             4740 non-null   object
#  10  plot_keywords              4890 non-null   object
#  11  director_name              4939 non-null   object
#  12  actor_1_name               5036 non-null   object
# ...

# %%
movies.dtypes #Arroja los tipos de datos
# Out:
# movie_title                   object
# title_year                   float64
# color                         object
# aspect_ratio                 float64
# duration                     float64
# language                      object
# country                       object
# duration.1                   float64
# genres                        object
# content_rating                object
# plot_keywords                 object
# director_name                 object
# actor_1_name                  object
# actor_2_name                  object
# actor_3_name                  object
# cast_total_facebook_likes      int64
# budget                       float64
# imdb_score                   float64
# gross                        float64
# dtype: object

# %%
movies.dtypes == float #Compara cada uno de los datos sin necesidad de un for
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
#Aritmetica de booleanos - | = or
(movies.dtypes == float) | (movies.dtypes == int)
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
num = (movies.dtypes == float) | (movies.dtypes == int)
#print(num[0])
colum_numeric=list()

colum_str=list()
for llave,valor in num.items():#Lo leemos como diccionario donde la llave es la columna y el valor es true si es int or float
    if valor == True:
        colum_numeric.append(llave)
    else:
        colum_str.append(llave)
        
print(colum_str)
print(colum_numeric)
# Out:
# ['movie_title', 'color', 'language', 'country', 'genres', 'content_rating', 'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'cast_total_facebook_likes']
# ['title_year', 'aspect_ratio', 'duration', 'duration.1', 'budget', 'imdb_score', 'gross']

# %%
movies[colum_numeric] #Nos trae todas las columnas numericas
# Out:
#       title_year  aspect_ratio  duration  duration.1       budget  imdb_score  \
# 0         2009.0          1.78     178.0       178.0  237000000.0         7.9
# 1         2007.0          2.35     169.0       169.0  300000000.0         7.1
# 2         2015.0          2.35     148.0       148.0  245000000.0         6.8
# 3         2012.0          2.35     164.0       164.0  250000000.0         8.5
# 4            NaN           NaN       NaN         NaN          NaN         7.1
# ...          ...           ...       ...         ...          ...         ...
# 5038      2013.0           NaN      87.0        87.0          NaN         7.7
# 5039         NaN         16.00      43.0        43.0          NaN         7.5
# 5040      2013.0           NaN      76.0        76.0       1400.0         6.3
# 5041      2012.0          2.35     100.0       100.0          NaN         6.3
# 5042      2004.0          1.85      90.0        90.0       1100.0         6.6
#
#             gross
# ...

# %%
movies[colum_str]
# Out:
#                                             movie_title  color language  \
# 0                                               Avatar   Color  English
# 1             Pirates of the Caribbean: At World's End   Color  English
# 2                                              Spectre   Color  English
# 3                                The Dark Knight Rises   Color  English
# 4     Star Wars: Episode VII - The Force Awakens    ...    NaN      NaN
# ...                                                 ...    ...      ...
# 5038                           Signed Sealed Delivered   Color  English
# 5039                         The Following               Color  English
# 5040                              A Plague So Pleasant   Color  English
# 5041                                  Shanghai Calling   Color  English
# 5042                                 My Date with Drew   Color  English
#
#      country                           genres content_rating  \
# ...

# %%
movies_numeric=movies[colum_numeric]

# %%
#Estadisticas de las columnas numericas
movies_numeric.describe() #std=desviacion estandar , mean = promedio
# Out:
#         title_year  aspect_ratio     duration   duration.1        budget  \
# count  4935.000000   4714.000000  5028.000000  5028.000000  4.551000e+03
# mean   2002.470517      2.220403   107.201074   107.201074  3.975262e+07
# std      12.474599      1.385113    25.197441    25.197441  2.061149e+08
# min    1916.000000      1.180000     7.000000     7.000000  2.180000e+02
# 25%    1999.000000      1.850000    93.000000    93.000000  6.000000e+06
# 50%    2005.000000      2.350000   103.000000   103.000000  2.000000e+07
# 75%    2011.000000      2.350000   118.000000   118.000000  4.500000e+07
# max    2016.000000     16.000000   511.000000   511.000000  1.221550e+10
#
#         imdb_score         gross
# count  5043.000000  4.159000e+03
# mean      6.442138  4.846841e+07
# std       1.125116  6.845299e+07
# min       1.600000  1.620000e+02
# 25%       5.800000  5.340988e+06
# 50%       6.600000  2.551750e+07
# 75%       7.200000  6.230944e+07
# max       9.500000  7.605058e+08

# %%
#Estadisticas de las columnas de texto

# %%
#Podemos llamar directamente desde la api de pandas 
movies_numeric['duration'].hist() # Minutos

# %%
movies_numeric['imdb_score'].hist() #Calidad de las peliculas segun imdb

# %%
movies_numeric['budget'].hist() #Presupuesto de las peliculas

# %% [markdown]
# Como se puede observar hay una anomalia en los datos por eso vamos a debuggear Una tecnica muy usada en pandas para debuggear  es boolean filtering basicamente construimos una serie de booleanos con el mismo indice  que nuestro dataframe (la serie clasicamente la llamamos mask)

# %%
#cuales peliculas son mayores a un millon y que me muestre las que si y las que no
(movies_numeric['budget'] > 1e9).value_counts()
# Out:
# False    5037
# True        6
# Name: budget, dtype: int64

# %%
#Mask
mask = (movies_numeric['budget'] > 1e9) 
movies[mask] #Me muestra solo las lineas que el presupuesto de la pelicula sea mayor a un millon , pero la persona
#Que trajo la informacion de la base de datos trajo todo en yenes no considero la moneda entonces
# Out:
#              movie_title  title_year  color  aspect_ratio  duration  \
# 2323  Princess Mononoke       1997.0  Color          1.85     134.0
# 2334           Steamboy       2004.0  Color          1.85     103.0
# 2988           The Host       2006.0  Color          1.85     110.0
# 3005           Fateless       2005.0  Color          2.35     134.0
# 3423              Akira       1988.0  Color          1.85     124.0
# 3859     Lady Vengeance       2005.0  Color          2.35     112.0
#
#        language      country  duration.1  \
# 2323   Japanese        Japan       134.0
# 2334   Japanese        Japan       103.0
# 2988     Korean  South Korea       110.0
# 3005  Hungarian      Hungary       134.0
# 3423   Japanese        Japan       124.0
# 3859     Korean  South Korea       112.0
#
#                                                  genres content_rating  \
# 2323                        Adventure|Animation|Fantasy          PG-13
# ...

# %%
#print(os.getcwd())
pd.read_csv(r'DATOS\thenumbers.csv')
# Out:
#       Unnamed: 0                                movie_name  domestic_gross  \
# 0              0                                    Avatar       760507625
# 1              1      Star Wars Ep. VII: The Force Awakens       936662225
# 2              2  Pirates of the Caribbean: At World's End       309420425
# 3              3                                   Spectre       200074175
# 4              4                     The Dark Knight Rises       448139099
# ...          ...                                       ...             ...
# 4336        5157                           The Mongol King             900
# 4337        5160                   Signed Sealed Delivered               0
# 4338        5161                          Shanghai Calling           10443
# 4339        5162                      A Plague So Pleasant               0
# 4340        5163                         My Date With Drew          181041
#
# ...

# %%
financieros = pd.read_csv(r'DATOS\thenumbers.csv')

# %%
#Limpiamos los datos
financieros = financieros[['movie_title','production_budget','worldwide_gross']]

# %%
financieros
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4336                                   The Mongol King                7000
# 4337                           Signed Sealed Delivered                5000
# 4338                                  Shanghai Calling                3967
# 4339                              A Plague So Pleasant                1400
# 4340                                 My Date with Drew                1100
#
#       worldwide_gross
# 0          2783918982
# ...

# %%
financieros.shape
# Out:
# (4341, 3)

# %%
movies_numeric
# Out:
#       title_year  aspect_ratio  duration  duration.1       budget  imdb_score  \
# 0         2009.0          1.78     178.0       178.0  237000000.0         7.9
# 1         2007.0          2.35     169.0       169.0  300000000.0         7.1
# 2         2015.0          2.35     148.0       148.0  245000000.0         6.8
# 3         2012.0          2.35     164.0       164.0  250000000.0         8.5
# 4            NaN           NaN       NaN         NaN          NaN         7.1
# ...          ...           ...       ...         ...          ...         ...
# 5038      2013.0           NaN      87.0        87.0          NaN         7.7
# 5039         NaN         16.00      43.0        43.0          NaN         7.5
# 5040      2013.0           NaN      76.0        76.0       1400.0         6.3
# 5041      2012.0          2.35     100.0       100.0          NaN         6.3
# 5042      2004.0          1.85      90.0        90.0       1100.0         6.6
#
#             gross
# ...

# %%
movies_numeric = pd.concat([movies_numeric,movies['movie_title']],axis=1) 
#Por defecto la concatenacion se hace linea por linea
# que seria axis=0 , aqui cambiamos la concatenacion de columa por columna para que valide cada una y asi concatenar bien el tittle

# %%
movies_numeric
# Out:
#       title_year  aspect_ratio  duration  duration.1       budget  imdb_score  \
# 0         2009.0          1.78     178.0       178.0  237000000.0         7.9
# 1         2007.0          2.35     169.0       169.0  300000000.0         7.1
# 2         2015.0          2.35     148.0       148.0  245000000.0         6.8
# 3         2012.0          2.35     164.0       164.0  250000000.0         8.5
# 4            NaN           NaN       NaN         NaN          NaN         7.1
# ...          ...           ...       ...         ...          ...         ...
# 5038      2013.0           NaN      87.0        87.0          NaN         7.7
# 5039         NaN         16.00      43.0        43.0          NaN         7.5
# 5040      2013.0           NaN      76.0        76.0       1400.0         6.3
# 5041      2012.0          2.35     100.0       100.0          NaN         6.3
# 5042      2004.0          1.85      90.0        90.0       1100.0         6.6
#
# ...

# %%
movies[['gross','movie_title']].head()
# Out:
#          gross                                        movie_title
# 0  760505847.0                                            Avatar
# 1  309404152.0          Pirates of the Caribbean: At World's End
# 2  200074175.0                                           Spectre
# 3  448130642.0                             The Dark Knight Rises
# 4          NaN  Star Wars: Episode VII - The Force Awakens    ...

# %%
movies_v2 = pd.merge(financieros,movies_numeric,on='movie_title',how='left') #Haga un merge en la columna movie_title y deje
# y lo inserta al lado izquierdo lo que estaba en financieros que no estaba en numeric era production_budget y worldwide_gross
movies_v2
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4380                                   The Mongol King                7000
# 4381                           Signed Sealed Delivered                5000
# 4382                                  Shanghai Calling                3967
# 4383                              A Plague So Pleasant                1400
# 4384                                 My Date with Drew                1100
#
# ...

# %%
#Datos faltantes
movies_v2.notnull()
# Out:
#       movie_title  production_budget  worldwide_gross  title_year  \
# 0            True               True             True        True
# 1            True               True             True       False
# 2            True               True             True        True
# 3            True               True             True        True
# 4            True               True             True        True
# ...           ...                ...              ...         ...
# 4380         True               True             True        True
# 4381         True               True             True        True
# 4382         True               True             True        True
# 4383         True               True             True        True
# 4384         True               True             True        True
#
#       aspect_ratio  duration  duration.1  budget  imdb_score  gross
# 0             True      True        True    True        True   True
# ...

# %%
#La cantidad de null que tenemos por columna
help(pd.Series.value_counts) #Ver documentacion
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
#         Don't include counts of NaN.
#
#     Returns
#     -------
#     Series
#
#     See Also
# ...

# %%
movies_v2.notnull().apply(pd.Series.value_counts)
# Out:
#        movie_title  production_budget  worldwide_gross  title_year  \
# False          NaN                NaN              NaN          27
# True        4385.0             4385.0           4385.0        4358
#
#        aspect_ratio  duration  duration.1  budget  imdb_score  gross
# False           274        13          13     335         NaN    671
# True           4111      4372        4372    4050      4385.0   3714

# %%
(movies_v2 != 0 ).apply(pd.Series.value_counts)  #Columna por columna los que son diferentes de 0
#apply(pd.Series.value_counts) ->COLUMNA POR COLUMNA 

# worldwide_gross = es nuestra variable objetivo , por ende no puede tener valores en 0
# Out:
#        movie_title  production_budget  worldwide_gross  title_year  \
# False          NaN                NaN              281         NaN
# True        4385.0             4385.0             4104      4385.0
#
#        aspect_ratio  duration  duration.1  budget  imdb_score   gross
# False           NaN       NaN         NaN     NaN         NaN     NaN
# True         4385.0    4385.0      4385.0  4385.0      4385.0  4385.0

# %%
available =((movies_v2 != 0 ) & (movies_v2.notnull()))

# %%
available.all(axis=1)
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 4378     True
# 4379    False
# 4380    False
# 4382    False
# 4384     True
# Length: 4104, dtype: bool

# %%
available.all(axis=1).value_counts()
# Out:
# True     3413
# False     691
# dtype: int64

# %%
mask = available['worldwide_gross'] #Como nuestra variable objetivo es  worldwide_gross no puede contener valores en 0 o en null

# %%
mask #Hacemos la mascara como la que hicimos arriba
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4378    True
# 4379    True
# 4380    True
# 4382    True
# 4384    True
# Name: worldwide_gross, Length: 4104, dtype: bool

# %% [raw]
# Filtramos la mascara solo aquellos valores que no sean null o sean 0 , los quitamos de nuestros datos , solo los quitamos los que son de nuestra variable objetivo
#
# La objetivo es con la que entrenamos el algoritmo

# %%
movies_v2 = movies_v2[mask]

# %%
movies_v2
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4378                                            Primer                7000
# 4379                                            Cavite                7000
# 4380                                   The Mongol King                7000
# 4382                                  Shanghai Calling                3967
# 4384                                 My Date with Drew                1100
#
# ...

# %%
((movies_v2 != 0 ) & (movies_v2.notnull())).worldwide_gross.value_counts()
# Out:
# True    4104
# Name: worldwide_gross, dtype: int64

# %%
movies_v2
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4378                                            Primer                7000
# 4379                                            Cavite                7000
# 4380                                   The Mongol King                7000
# 4382                                  Shanghai Calling                3967
# 4384                                 My Date with Drew                1100
#
# ...

# %%
#Eliminamos movie_title
movies_v2.drop('movie_title',axis=1)
# Out:
#       production_budget  worldwide_gross  title_year  aspect_ratio  duration  \
# 0             425000000       2783918982      2009.0          1.78     178.0
# 1             306000000       2058662225         NaN           NaN       NaN
# 2             300000000        963420425      2007.0          2.35     169.0
# 3             300000000        879620923      2015.0          2.35     148.0
# 4             275000000       1084439099      2012.0          2.35     164.0
# ...                 ...              ...         ...           ...       ...
# 4378               7000           841926      2004.0          1.85      77.0
# 4379               7000            71644      2005.0           NaN      80.0
# 4380               7000              900      2005.0           NaN      84.0
# 4382               3967            10443      2012.0          2.35     100.0
# 4384               1100           181041      2004.0          1.85      90.0
#
# ...

# %%
#Eliminamos duration de la pelicula
movies_v2.drop('duration',axis=1)
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4378                                            Primer                7000
# 4379                                            Cavite                7000
# 4380                                   The Mongol King                7000
# 4382                                  Shanghai Calling                3967
# 4384                                 My Date with Drew                1100
#
# ...

# %%
#Eliminamos duration de la pelicula
movies_v2.drop('duration.1',axis=1)
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4378                                            Primer                7000
# 4379                                            Cavite                7000
# 4380                                   The Mongol King                7000
# 4382                                  Shanghai Calling                3967
# 4384                                 My Date with Drew                1100
#
# ...

# %%
movies_v2
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4378                                            Primer                7000
# 4379                                            Cavite                7000
# 4380                                   The Mongol King                7000
# 4382                                  Shanghai Calling                3967
# 4384                                 My Date with Drew                1100
#
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
movies_v2
# Out:
#                                             movie_title  production_budget  \
# 0                                               Avatar           425000000
# 1     Star Wars: Episode VII - The Force Awakens    ...          306000000
# 2             Pirates of the Caribbean: At World's End           300000000
# 3                                              Spectre           300000000
# 4                                The Dark Knight Rises           275000000
# ...                                                 ...                ...
# 4378                                            Primer                7000
# 4379                                            Cavite                7000
# 4380                                   The Mongol King                7000
# 4382                                  Shanghai Calling                3967
# 4384                                 My Date with Drew                1100
#
# ...

# %%
movies_v2 = movies_v2.drop('duration',axis=1)

# %%
movies_v2 = movies_v2.drop('movie_title',axis=1)

# %%
movies_v2
# Out:
#       production_budget  worldwide_gross  title_year  aspect_ratio  \
# 0             425000000       2783918982      2009.0          1.78
# 1             306000000       2058662225         NaN           NaN
# 2             300000000        963420425      2007.0          2.35
# 3             300000000        879620923      2015.0          2.35
# 4             275000000       1084439099      2012.0          2.35
# ...                 ...              ...         ...           ...
# 4378               7000           841926      2004.0          1.85
# 4379               7000            71644      2005.0           NaN
# 4380               7000              900      2005.0           NaN
# 4382               3967            10443      2012.0          2.35
# 4384               1100           181041      2004.0          1.85
#
#       duration.1       budget  imdb_score        gross
# 0          178.0  237000000.0         7.9  760505847.0
# ...

# %%
values=imputer.fit_transform(movies_v2)

# %%
values
# Out:
# array([[4.25000000e+08, 2.78391898e+09, 2.00900000e+03, ...,
#         2.37000000e+08, 7.90000000e+00, 7.60505847e+08],
#        [3.06000000e+08, 2.05866222e+09, 2.00213073e+03, ...,
#         4.04553863e+07, 7.10000000e+00, 4.83193329e+07],
#        [3.00000000e+08, 9.63420425e+08, 2.00700000e+03, ...,
#         3.00000000e+08, 7.10000000e+00, 3.09404152e+08],
#        ...,
#        [7.00000000e+03, 9.00000000e+02, 2.00500000e+03, ...,
#         3.25000000e+03, 7.80000000e+00, 4.83193329e+07],
#        [3.96700000e+03, 1.04430000e+04, 2.01200000e+03, ...,
#         4.04553863e+07, 6.30000000e+00, 1.04430000e+04],
#        [1.10000000e+03, 1.81041000e+05, 2.00400000e+03, ...,
#         1.10000000e+03, 6.60000000e+00, 8.52220000e+04]])

# %%
x = pd.DataFrame(values)

# %%
x.columns = movies_v2.columns

# %%
x.index=movies_v2.index

# %%
x.head()
# Out:
#    production_budget  worldwide_gross   title_year  aspect_ratio  duration.1  \
# 0        425000000.0     2.783919e+09  2009.000000      1.780000  178.000000
# 1        306000000.0     2.058662e+09  2002.130733      2.126976  108.577186
# 2        300000000.0     9.634204e+08  2007.000000      2.350000  169.000000
# 3        300000000.0     8.796209e+08  2015.000000      2.350000  148.000000
# 4        275000000.0     1.084439e+09  2012.000000      2.350000  164.000000
#
#          budget  imdb_score         gross
# 0  2.370000e+08         7.9  7.605058e+08
# 1  4.045539e+07         7.1  4.831933e+07
# 2  3.000000e+08         7.1  3.094042e+08
# 3  2.450000e+08         6.8  2.000742e+08
# 4  2.500000e+08         8.5  4.481306e+08

# %%
x.to_csv('DATOS\x.csv,index=False)
# Out:
#   File "<ipython-input-143-3c640f921b05>", line 1
#     x.to_csv('DATOS\x.csv',index=False)
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 5-6: truncated \xXX escape
